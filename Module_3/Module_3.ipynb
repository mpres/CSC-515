# %%
# this project is for Module_3 CSC-515 Computer Vision. 1/20/26
# Author/Date:Mpresley 1/20/26
# Purpose: upload image to opencv and draw red boxes around the eyes and green circles around the face
# Outline: 1. import modules, 2. get image 3. draw box around eyes (after establishing center of each eye), 4. draw circle around face (after getting the center of face cordinates, 5. Save annoated image

# %%
#Get opencv2
# %pip install opencv2
# Out:
# ERROR: Could not find a version that satisfies the requirement opencv2 (from versions: none)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: /Users/mpresley84/PycharmProjects/CSC-515/.venv/bin/python -m pip install --upgrade pip
# ERROR: No matching distribution found for opencv2
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2 as cv

#Step extract image
face_img = cv.imread("front_face.jpg")

#Step
